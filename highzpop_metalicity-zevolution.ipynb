# %%
using Pkg
Pkg.activate(joinpath(@__DIR__, ".."))
#Pkg.add(PackageSpec(url="https://git.ligo.org/will-farr/pisnmassfunctions.jl.git"))
#Pkg.resolve()
Pkg.instantiate()
# Out:
#   Activating environment at `~/Projects/GW/PISN-Cali/O3a-PISN/Project.toml`

# %%
using Cosmology
using HDF5
using LaTeXStrings
using Statistics
using StatsBase
using StatsPlots
using Unitful
using UnitfulAstro
#using O3aPISN
using PISNMassFunctions
using Plots
using Interpolations
using Turing
using LogExpFunctions
using JSON3
using PairPlots
using AdvancedHMC

default(fmt=png)

# %%
alpha_true = 4.8
beta_true = 2.1
gamma_true = 0.2
kappa_true = 3.1
z_p_true = 1.9
MMin_true = 7.1
MMax_true = 49.0
smooth_min_true = 0.17
smooth_max_true = 0.15
H0_true = 67.74
Om_true = 0.3075
w_true = -1.0
Meh_true = 60.0
Mel_true = 15.0

H0 = H0_true
Om = Om_true
w = w_true
mmax_true = MMax_true
mmin_true = MMin_true
smin = smooth_min_true
smax = smooth_max_true
zp_true = z_p_true
dH = 299.792/H0
# Out:
# 4.4256273988780634

# %%
qmin = 0.1
N = 1000
Nfullsamp = 120
Nsamp = 32
Ninterp = 1024
zmax = 20

a = 288356593172758950956953087364047537605
# Out:
# 288356593172758950956953087364047537605

# %%
using Random
rng = Random.Random.MersenneTwister(a)
# Out:
# MersenneTwister(0xd8ef75b1de0af2710808c722832785c5)

# %%
function fsmooth(m, ml, mh, sl, sh)
    return cdf.(Normal(log(ml), sl), log(m)) * (1 - cdf.(Normal(log(mh), sh), log(m)))
end
# Out:
# fsmooth (generic function with 1 method)

# %%
ms = 10 .^ range(log10(3), log10(100), length=128)

function meshgrid(x, y)
    X = [i for i in x, j in 1:length(y)]
    Y = [j for i in 1:length(x), j in y]
    return X, Y
end

function PMScalc(m1s, m2s)
    return m1s^(-alpha_true)*m2s^beta_true*fsmooth(m1s, MMin_true, MMax_true, smin, smax)*fsmooth(m2s, MMin_true, MMax_true, smin, smax)
end

function PMSmeshgrid(M1S, M2S)
    n = length(M1S[:,1])
    PMS = [M1S[i,j] > M2S[i,j] ? PMScalc(M1S[i,j], M2S[i,j]) : 0 for i in 1:n, j in 1:n]
    return PMS
end

M1S, M2S = meshgrid(ms, ms)
PMS = PMSmeshgrid(M1S, M2S)
print(" ")

# %%
using Trapz

pm1 = [trapz(PMS[i,:], M2S[i,:]) for i in 1:128]
pm1 = abs.(pm1 ./ trapz(pm1, ms))
pm2 = [trapz(PMS[:,i], M1S[:,i]) for i in 1:128]
pm2 = abs.(pm2 ./ trapz(pm2, ms))

cm1 = abs.(cumtrapz(ms, pm1))
print(" ")

# %%
drawer_m1 = LinearInterpolation(cm1, ms)

function draw_m1_tapered(n=1, rng=rng)
    return drawer_m1(rand!(rng, zeros(n)))
end
# draw_m1_tapered(5)

function draw_m2_tapered(m1, n=1, rng=rng)

    pm2 = ms.^beta_true.*fsmooth.(ms, mmin_true, mmax_true, smin, smax)
    pm2 = -pm2 ./ trapz(pm2, ms)
    
    cm2 = cumtrapz(ms, pm2)
    drawer_m2_inv = LinearInterpolation(ms, cm2)
    drawer_m2 = LinearInterpolation(cm2, ms)
    c_max = drawer_m2_inv(m1)
    
    return drawer_m2(rand!(rng, zeros(n)).*c_max)
end

# draw_m2_tapered(25.7,5)
# Out:
# draw_m2_tapered (generic function with 3 methods)

# %%
function Ez(z, Om, Ol, w0, wm) 
    opz = 1.0 .+ z
    opz2 = opz .* opz
    opz3 = opz2 .* opz
    Ok = 1.0 - Om - Ol
    return (Om .* opz3 .^(1.0+wm) .+ Ol .* opz3 .^(1.0 + w0) .+ Ok .* opz2) .^0.5
end

function dC(zs, dH, Om, Ol, w0, wm)
    n = length(zs)
    igrd = [dH/Ez(zs[i], Om, Ol, w0, wm) for i in 1:n]
    dCs = PISNMassFunctions.cumtrapz(zs, igrd)

    return dCs
end
    
function dM_of_dC(dCs, dH, Om, Ol, w0, wm)
    n = length(dCs)
    Ok = 1.0 - Om - Ol

    if Ok < 0
    dMs = dH ./ (-Ok)^0.5 .* sin.(dCs .* (-Ok)^0.5 ./ dH)
    elseif Ok > 0
    dMs = dH ./ (Ok)^0.5 .* sinh.(dCs .* (Ok)^0.5 ./ dH)
    else
    dMs = dCs
    end

    return dMs
end

function dL_of_dM(dMs, zs)

    dLs = dMs.*(1 .+ zs)

    return dLs
end

function diff_comoving_volume(zs, H0, Om, Ol, w0, wm)
    dcs = dC(zs, 299.792/H0, Om, Ol, w0, wm)
    return 299.792 ./ H0 .* (dM_of_dC(dcs, 299.792/H0, Om, Ol, w0, wm) .^ 2.0) ./ Ez(zs, Om, Ol, w0, wm)
end

function dLs(zs, H0, Om, Ol, w0, wm)
    dH = 299.792/H0
    return dL_of_dM(dC(zs, dH, Om, Ol, w0, wm), zs)
end
# Out:
# dLs (generic function with 1 method)

# %%
function draw_z(zp, gamma = gamma_true, kappa = kappa_true, size=1, zmax=15, rng=rng)
    zs = expm1.(range(log(1), log(1+zmax), length=1024)) 
    diff_co_v = diff_comoving_volume(zs, H0, Om, 1-Om, -1, 0)
    pz_interp = (1 .+ zs).^gamma./(1 .+ ((1 .+ zs)./(1 + zp)).^kappa) .* diff_co_v./(1 .+ zs)
    pz_interp = -pz_interp ./ trapz(pz_interp, zs)
    cz = cumtrapz(zs, pz_interp)
    drawer_z = LinearInterpolation(cz, zs)
    return drawer_z(rand!(rng, zeros(size)))
end
# Out:
# draw_z (generic function with 6 methods)

# %%
m1s_true_old = draw_m1_tapered(N)    
m2s_true_old = draw_m2_tapered(m1s_true_old, N)

qs_true_old = m2s_true_old ./ m1s_true_old
zs_true_old = draw_z(zp_true, gamma_true, kappa_true, N)

zint = expm1.(range(log(1), log(1+25), length=1024)) 
dint = dLs(zint, H0, Om, 1-Om, -1, 0) #[comoving_transverse_dist(cosmo, z[i]) for i in 1:1024] .* (1 .+ z) ./ 1000 ./ u"Mpc" # luminosity distance
d_of_z = LinearInterpolation(zint, dint)
z_of_d = LinearInterpolation(dint, zint)
dls_true_old = d_of_z(zs_true_old)
print(" ")

# %% [markdown]
# The posterior samples show some structure in the $m_{1,\mathrm{detector}}$ vs $d_L$ plane:

# %%
d1 = d_of_z(1)

function sigma_d(d)
    return 3e-4*d*d
end
function sigma_m1(m1, d)
    return 0.01*m1*d/d1
end
function sigma_q(q, d)
    return 0.01*q*d/d1
end
# Out:
# sigma_q (generic function with 1 method)

# %%
function log_smooth(m, ml, sl, mh, sh)
    return log.(cdf.(Normal(log(ml), sl), log.(m))) .+ log.(1 .- cdf.(Normal(log(mh), sh), log.(m)))
end
# Out:
# log_smooth (generic function with 1 method)

# %%
function log_ddLdz(dl, z, dH, Om, Ol, w0, wm)
    n = length(dl)
    Ok = 1.0 - Om - Ol
    dc = dl ./ (1 .+ z)

    if Ok < 0
        fac = cos.(dc .* sqrt(-Ok) ./ dH)
    elseif Ok > 0
        fac = cosh.(dc .* sqrt(Ok) ./ dH)
    else
        fac = 1.0
    end

    H0 = 299.792/dH

    eofzs = Ez(z, Om, Ol, w0, wm)  #[EofZ(cosmo, z[i]) for i in 1:n]
    log_d = log.(dl ./ (1 .+ z) .+ (1 .+ z) .* dH ./ eofzs .* fac)

    return log_d
end

function log_dVdz(dl, z, dH, Om, Ol, w0, wm)
    n = length(dl)
    
    Ok = 1.0 - Om - Ol
    dc = dl ./ (1 .+ z)

    if Ok < 0
        fac = cos.(dc .* sqrt(-Ok) ./ dH)
    elseif Ok > 0
        fac = cosh.(dc .* sqrt(Ok) ./ dH)
    else
        fac = 1.0
    end
    
    log_4pi = log(4.0*pi)
    log_dH = log(dH)
    H0 = 299.792/dH

    eofzs = Ez(z, Om, Ol, w0, wm)
    log_dc = log.(dc)
    log_dV = log_dH .+ 2.0 .* log_dc - log.(eofzs) .+ log.(fac) #.+ log_4pi

    return log_dV
end
# Out:
# log_dVdz (generic function with 1 method)

# %%
function log_dNdm1dm2dz(m1s, m2s, dls, zs, alpha, beta, mmin, smin, mmax, smax, gamma, zp, kappa, dH, Om, Ol, w0, wm, memin, memax)
    
    n = length(m1s)
    log_dH = log(dH)

    mzmax = mmax .+ (memax .-mmax) .* zs./20
    mzmin = mmin .+ (memin .-mmin) .* zs./20
    log_dV = log_dVdz(dls, zs, dH, Om, Ol, w0, wm)
    log_s1 = [log_smooth(m1s[i], mzmin[i], smin, mzmax[i], smax) for i in 1:n]
    log_s2 = [log_smooth(m2s[i], mzmin[i], smin, mzmax[i], smax) for i in 1:n]
    
    log_dN = -alpha .* log.(m1s) .+ beta .* log.(m2s) .+ (gamma-1) .* log1p.(zs) .- log1p.(((1 .+ zs) ./ (1+zp)) .^ kappa) .+ log_dV .+ log_s1 .+ log_s2

    return log_dN

end

function log_dNdm1dqdd_of_dm1dm2dz(log_dN, m1s, dls, zs, dH, Om, Ol, w0, wm) 
    n = length(log_dN)
    log_dd = log_ddLdz(dls, zs, dH, Om, Ol, w0, wm)

    logj = log.(m1s) .- log_dd #.- log1p.(zs)

    log_dN_m1obsqd = log_dN .+ logj

    return log_dN_m1obsqd
end
# Out:
# log_dNdm1dqdd_of_dm1dm2dz (generic function with 1 method)

# %%
function draw_injections(N)
    mmin = 4
    mmax = 500
    zdist = truncated(Normal(5.1, 3.4), 0.0001, 15)
    m1s = exp.(rand(Uniform(log(mmin), log(mmax)), N))
    qs = rand(Uniform(0, 1), N)
    zs = rand(zdist, N)

    draw_wts = 1 ./ (m1s.*(log(mmax)-log(mmin))) .* pdf.(zdist, zs)

    (m1s, qs, zs, draw_wts)
end

"""
    draw_population(Ndraw=100; safety_factor=10)

Returns `(m1s, qs, zs, pdraws, norm, Neff_norm)`, draws from the population.

`norm` is an estimate of the integral of the population density over all masses
and redshifts; the expected number of merger events per year is `θ_mock.R * norm`.

`Neff_norm` is the number of effective samples in the norm computation (so the
fractional uncertainty in the normalization is `1/sqrt(Neff_norm)`).

The method used is rejection sampling; `Ndraw` draws will be taken from a simple
distribution, and then `Neff_norm / safety_factor` rejection samples (some
repeated) will be returned.
"""

function draw_population(Ndraw=10000,  Nobs = 100; safety_factor = 10)
    m1d, qd, zd, draw_wt = draw_injections(Ndraw)
    z = expm1.(range(log(1), log(1+25), length=1024)) 
    d = dLs(z, H0, Om, 1-Om, -1, 0) #[comoving_transverse_dist(cosmo, z[i]) for i in 1:1024] .* (1 .+ z) ./ 1000 ./ u"Mpc" # luminosity distance
    d_of_z = LinearInterpolation(z, d)
    
    m1s = m1d ./ (1 .+ zd)
    m2s = m1s .* qd
    ds = [d_of_z(z) for z in zd]

    log_dN_mmz = log_dNdm1dm2dz(m1s, m2s, ds, zd, alpha_true, beta_true, mmin_true, smin, mmax_true, smax, gamma_true, zp_true, kappa_true, dH, Om, 1-Om, w, 0.0, Meh_true, Mel_true)
    log_dN = log_dNdm1dqdd_of_dm1dm2dz(log_dN_mmz, m1s, ds, zd, dH, Om, 1-Om, w, 0.0)

    log_pop_wt = log_dN
    
    pop_wts = exp.(log_pop_wt)
    wts = pop_wts ./ draw_wt .* exp.(log_ddLdz(ds, zd, dH, Om, 1-Om, w, 0.0)) ./ (1 .+ zd)

    norm = sum(wts) / length(wts)
    Nex = sum(wts) / maximum(wts)
    Neff_norm = sum(wts)^2 / sum(wts.*wts)
    
    @assert Nex > 10
    
    inds = sample(1:length(m1d), weights(wts), Nobs * 4)
    #inds = maximum(wts) .* rand(Ndraw) .< wts
    
    m1d[inds], qd[inds], zd[inds], ds[inds], wts[inds], norm, Neff_norm, draw_wt[inds], pop_wts[inds]
end
# Out:
# draw_population (generic function with 3 methods)

# %%
m1d_true, qs_true, zs_true, draw_wt = draw_population(100000,  cld(1000,4))
m1s_true = m1d_true ./ (1 .+ zs_true)
dls_true = d_of_z(zs_true)
print(" ")

# %%
histogram(dls_true_old, bins = 0:1:100, alpha = 0.4)
histogram!(dls_true, bins = 0:1:100, alpha = 0.4)

# %%
m1_obs = Vector{Float64}()
qs_obs = Vector{Float64}()
dls_obs = Vector{Float64}()

logwts_obs = Vector{Float64}()

Nobs = N

for i in 1:N
    m1, q, d, z = m1s_true[i], qs_true[i], dls_true[i], zs_true[i]
    
    m1obstemp = zeros(0)
    qobstemp = zeros(0)
    dlobstemp = zeros(0)
    logwttemp = zeros(0)
    
    sigmam1 = sigma_m1(m1*(1+z), d)
    sigmaq = sigma_q(q, d)
    sigmadl = sigma_d(d)
    for j in 1:Nfullsamp
    
    mo = -1.0
    sm1 = 0
    while mo < 0
        sm1 = randn!(rng, zeros(1))[1] * sigmam1
        mo = sm1 + m1*(1+z)
    end
    push!(m1obstemp, mo)
    
    qo = -1.0
    sq = 0
    while qo < qmin || qo > 1
        sq = randn!(rng, zeros(1))[1] * sigmaq
        qo = sq + q
    end
    push!(qobstemp, qo)
    
    d0 = -1.0
    sdl = 0
    while d0 < 0
        sdl = randn!(rng, zeros(1))[1] * sigmadl
        d0 = sdl + d
    end
    push!(dlobstemp,d0)
        

    zo = z_of_d(d0)    
    m1s = mo / (1 + zo)
    m2s = qo * m1s


    log_dN_mmz = log_dNdm1dm2dz([m1s], [m2s], [d0], [zo], alpha_true, beta_true, mmin_true, smin, mmax_true, smax, gamma_true, zp_true, kappa_true, dH, Om, 1-Om, w, 0.0, Meh_true, Mel_true)
    log_dN = log_dNdm1dqdd_of_dm1dm2dz(log_dN_mmz, [m1s], [d0], [zo], dH, Om, 1-Om, w, 0.0)

    log_wt = log_dN[1]
    #log_wt = logpdf(Normal(0,sigmam1),sm1) + logpdf(Normal(0,sigmaq),sq) + logpdf(Normal(0,sigmadl),sdl)
    push!(logwttemp,log_wt)
        
    end
    append!(m1_obs, m1obstemp)
    append!(qs_obs, qobstemp)
    append!(dls_obs, dlobstemp)
    append!(logwts_obs, logwttemp)

end

# %%
m1_obs = reshape(m1_obs, (Nfullsamp, Nobs))
qs_obs = reshape(qs_obs, (Nfullsamp, Nobs))
dls_obs = reshape(dls_obs, (Nfullsamp, Nobs))
logwts_obs = reshape(logwts_obs, (Nfullsamp, Nobs))

print(" ")

# %%
histogram(m1_obs[1,:], norm=true)

# %%
m1s_samp = Vector{Float64}()
qs_samp = Vector{Float64}()
dls_samp = Vector{Float64}()
logwt_samp = Vector{Float64}()

for i in 1:Nobs
    m1, q, d, logwt = m1_obs[:,i], qs_obs[:,i], dls_obs[:,i], logwts_obs[:,i]

    wts_numer = ones(length(m1))
    wts = wts_numer
    wts /= sum(wts)
    Neff = 1.0 / sum(wts.*wts)

    if Nsamp > Neff
        @warn "Drawing more samples ($(Nsamp)) than effective samples ($(Neff))"
    end

    c = sample(collect(1:length(m1)), weights(wts), Nsamp)

    append!(m1s_samp, m1[c])
    append!(qs_samp, q[c])
    append!(dls_samp, d[c])
    append!(logwt_samp, logwt[c])#./sum(logwt[c]).* Nsamp)
    
    
end

# %%
m1s_samp = reshape(m1s_samp, (Nsamp, Nobs))
qs_samp = reshape(qs_samp, (Nsamp, Nobs))
dls_samp = reshape(dls_samp, (Nsamp, Nobs))
logwt_samp = reshape(logwt_samp, (Nsamp, Nobs))

print(" ")

# %%
log_m1s_true = log.(m1s_true)
logit_qs_true = log.(qs_true) .- log.(1 .- qs_true)
log_dls_true = log.(dls_true)
print(" ")

# %%
Ndraws = 200000
pdraws = draw_population(Ndraws, Nobs)
m1s_draw = pdraws[1]
qs_draw = pdraws[2]
zs_draw = pdraws[3]
dls_draw = pdraws[4]
pts = pdraws[5]
popwts = pdraws[9]
println(Ndraws," ", length(m1s_draw)," ", pdraws[6]," ", pdraws[7])

#m1sel, qsel, dlsel, zsel, psel, Ndraw, Neff_norm = resample_selection(m1s_draw, qs_draw, zs_draw, pts, pdraws[5])
#println(Ndraw," ",Neff_norm)
m1sel, qsel, dlsel, zsel, psel, norm, Neff_norm = m1s_draw, qs_draw, dls_draw, zs_draw, pts, pdraws[6], pdraws[7]

Ndraw = length(psel)

println("Neff_norm: ", Neff_norm," norm: ",norm)


Nsel = length(m1sel)
zsel_cut = zsel[1:Nsel]
m1sel_cut = m1sel[1:Nsel]
qsel_cut = qsel[1:Nsel]
dlsel_cut = dlsel[1:Nsel]
psel_cut = popwts[1:Nsel] ./ norm #./sum(psel[1:Nsel]) .* Nsel
logpsel_cut = log.(psel_cut)

Ndraw_cut = round(Int, Ndraw * Nsel / length(m1sel))
# Out:
# 500000 12000 0.6135926069545816 10457.233612864695
# Neff_norm: 10457.233612864695 norm: 0.6135926069545816
# 12000

# %%
scatter(m1sel_cut, logpsel_cut .+ log(norm), alpha = 0.2,  ylim = [-15,9])
scatter!(m1sel_cut, log.(popwts), alpha = 0.2,  ylim = [-15,9])
scatter!(m1s_samp[1,:], logwt_samp[1,:], alpha = 0.2,  ylim = [-15,9])

# %%
scatter(dlsel_cut, logpsel_cut .+ log(norm), alpha = 0.1, ylim = [-15,2])
scatter!(dls_samp[2,:], logwt_samp[2,:],alpha = 0.2)

# %%
histogram(dls_samp[1,:], norm=true, alpha = 0.4)
histogram!(dlsel_cut, norm=true, alpha = 0.4)

# %%
histogram(m1s_samp[1,:], norm=true, alpha = 0.4)
histogram!(m1sel_cut, norm=true, alpha = 0.4)

# %%
zbins = [0,1,2,3,4,5,6,7,8]
mbins = [[],[],[],[],[],[],[],[]]
for i in 1:Ndraw
    if zsel[i]<=8
        k = ceil(Int,8-zsel[i])
        append!(mbins[k],m1sel[i]/(1+zsel[i]))
    end
end
mbins
# Out:
# 8-element Vector{Vector{Any}}:
#  [33.06442879948015, 30.160578981305893, 27.949558348667505, 31.096107860630255, 34.91399995508655]
#  [34.91850818269661, 31.68337443303459, 29.32371221719801, 44.5746186755289, 30.97876105010183, 27.139305433449557, 33.33613276182322, 24.722211388151944, 31.611564625398746, 24.410686121363437, 31.950941623116503, 24.60945812411808, 28.923769169863597, 24.89336945103714]
#  [25.961140301101242, 40.27800146125352, 31.472599560723996, 33.72589432063312, 31.975352041624976, 25.826219887020372, 27.349714604370032, 35.585618341664926, 25.347238844178122, 31.784055940860434  …  21.996732437348737, 32.45655917978449, 31.61453527306354, 31.792571091689076, 42.84589022581547, 30.14472175318337, 37.48349041025344, 27.853025641083903, 30.576745741359023, 31.213700296077977]
#  [29.437018072626454, 21.430671595326913, 16.64987026352453, 20.05549012821068, 23.112239041772558, 24.71865753534228, 22.35589889416188, 30.58207848618296, 33.38704387199293, 33.616561398845796  …  32.47990447842682, 20.32058302101885, 39.80439197205961, 27.821609720164748, 21.1662131487769, 32.16618022280738, 26.537207530484327, 20.33519675800165, 25.399865749041147, 31.77135224236647]
#  [35.38470724435513, 37.52584697023257, 26.41916203176645, 19.636396003598488, 36.97320132540296, 36.70135281330391, 34.94413266817305, 24.40365898547092, 27.135999877371628, 34.144349063247056  …  22.402935005936527, 24.88511159641899, 32.577779660868124, 50.864928358929035, 19.131736405126773, 38.80953634802151, 27.88945613631629, 25.18846487916369, 35.74289547144191, 37.65762975754383]
#  [16.172044530479884, 24.775213165639205, 46.863149711915874, 25.182451831785993, 46.97225915784736, 17.605962583490925, 30.53674201797463, 36.14818739268889, 16.897921355751787, 28.23264807145341  …  22.494192559175506, 29.463128185633924, 10.495846628289307, 24.41748825872835, 20.29113457516087, 28.244355454747176, 32.94592832001121, 24.48724878706802, 12.78278616700059, 14.471912900532766]
#  [34.20960992170389, 52.472241394887206, 15.877204615067523, 18.14867619479854, 14.615673555860623, 14.32575821517275, 31.093664782068767, 39.67033906718303, 23.059136325345396, 22.02285001482425  …  16.62488437066586, 45.19280764062384, 20.60828792146229, 40.5746854784369, 12.723892739713552, 19.632373234788588, 33.76247882024007, 24.028812382759877, 34.33387370399621, 28.170236253866292]
#  [31.93197599125654, 21.781886259049905, 19.19125404497238, 42.123196165194045, 9.973746139180765, 13.66994264530627, 20.722072399646265, 16.94256768736663, 12.980980432313004, 33.31462749954913  …  39.33238473088035, 34.13087593255703, 26.97704809160978, 10.641255070284139, 13.957459275236783, 12.11206520019418, 26.539737547362044, 14.34935249316371, 16.175905605668124, 32.17517371152943]

# %%
histogram(mbins[3], norm=true, alpha=0.4, bins = 0:4:60)
histogram!(mbins[4], norm=true, alpha=0.4, bins = 0:4:60)
histogram!(mbins[5], norm=true, alpha=0.4, bins = 0:4:60)
histogram!(mbins[6], norm=true, alpha=0.4, bins = 0:4:60)
histogram!(mbins[7], norm=true, alpha=0.4, bins = 0:4:60)
histogram!(mbins[8], norm=true, alpha=0.4, bins = 0:4:60)

# %%
ztemp = expm1.(range(0, log(11), length=1024))
dtemp = [d_of_z(ztemp[i]) for i in 1:1024]

#scatter(dls_obs, m1s_obs, yerror = sigma_m1s, xerror = sigma_dls, markersize = 3, linewidth = 0.5, alpha = 0.2)
scatter(dls_true, m1s_true.*(1 .+ [z_of_d(i) for i in dls_true]), markersize = 3, linewidth = 0.5, alpha = 0.2)
plot!(dtemp, mmax_true .* (1 .+ ztemp), color = :orange)
#scatter!(dls_obs, m1_obs, markersize = 3, linewidth = 0.5, alpha = 0.2)
plot!(dtemp, mmax_true .* (1 .+ ztemp), color = :orange)
plot!(size=(900,600))

# %%
"""
    effective_sample_number(weights)

Returns the effective number of samples from an array of importance weights.
"""
function effective_sample_number(weights)
    s = sum(weights)

    s*s / sum(weights.*weights)
end

"""
    draw_sample_index(wts[, size])

Return an index or indices into the array of `wts` drawn with probability
proportional to `wts`.
"""
function draw_sample_index(wts)
    cwts = cumsum(wts)
    r = rand()*cwts[end]
    searchsortedfirst(cwts, r)
end

function draw_sample_index(wts, size)
    cwts = cumsum(wts)
    [searchsortedfirst(cwts, rand()*cwts[end]) for i in 1:size]
end
# Out:
# draw_sample_index (generic function with 2 methods)

# %%
@model function highz_pop_simple(nobs, nsamp, nsel, ndraw, m1samp, qsamp, dlsamp, logwt_samp, m1sel, qsel, dlsel, log_psel)
    
    H0 ~ truncated(Normal(67.74, 15), 10, 100) #truncated(Normal(70.0, 10.0), 0, 100)
    Om ~ truncated(Normal(0.3075, 0.1), 0.01, 0.5) # truncated(Normal(0.3, 0.1), 0, 0.5)
    #Ok ~ truncated(Normal(0, 0.1), -1, 1) # Linearly related to Ol (=1-Ok-Om) (the sampled variable), so no Jacobian 
    #w0 ~ Normal(-1.0, 0.3)
    #wm ~ Normal(0.0, 0.2)

    # mass function prior
    alpha ~ truncated(Normal(4.8, 2.0),0, 100)
    beta ~ truncated(Normal(2.1, 2.0), 0, 100)
    mmin ~ truncated(Normal(7.1, 3.0), 0.1, 15)
    mmax ~ truncated(Normal(49.0, 7.0), mmin, 100) #truncated(Normal(49.0, 15.0), mmin, 100)
    smin ~ truncated(Normal(0.17, 0.02), 0.01, 2)
    smax ~ truncated(Normal(0.15, 0.01), 0.01, 2)

    # merger rate density prior
    gamma ~ truncated(Normal(0.2, 0.2),-5, 3)
    kappa ~ truncated(Normal(3.1, 2.0), gamma+1, 10)
    zp ~ truncated(Normal(1.9, 1.0), 0.001, 7)
    #memin ~ truncated(Normal(15.1, 3.0), 0.1, 30)
    #memax ~ truncated(Normal(60.0, 7.0), mmin, 100)
    
    #H0 = 67.74
    #Om = 0.3075
    Ok = 0
    w0 = -1.0
    wm = 0
    dH = 299.792/H0 # Gpc
    Ol = 1 - Ok - Om
    memin = mmin
    memax = mmax
    
    zinterp = expm1.(range(log(1), log(1+50), length=1024)) 
    ninterp = 1024
    dLinterp = dLs(zinterp, H0, Om, Ol, w0, wm) #[luminosity_dist(cosmosim, zinterp[i])/1000/ u"Mpc" for i in 1:ninterp]
    
    # neff
    for i in 2:ninterp
      if dLinterp[i] < dLinterp[i-1] 
        print("closed universe contracting at z = " + string(zinterp[i]))
        Turing.@addlogprob! -Inf
      end
    end
    
    z_of_d = LinearInterpolation(dLinterp, zinterp)
    d_of_z = LinearInterpolation(zinterp, dLinterp)
    
    if maximum(dlsel) > maximum(dLinterp) || minimum(dlsel) < minimum(dLinterp)
        Turing.@addlogprob! -Inf
    else
        
    zsel = [z_of_d(dlsel[i]) for i in 1:nsel]

    m1ssel = m1sel ./ (1 .+ zsel)
    m2ssel = qsel .* m1ssel

    log_dN_mmz_sel = log_dNdm1dm2dz(m1ssel, m2ssel, dlsel, zsel, alpha, beta, mmin, smin, mmax, smax, gamma, zp, kappa, dH, Om, Ol, w0, wm, memax, memin)
    log_dN_sel = log_dNdm1dqdd_of_dm1dm2dz(log_dN_mmz_sel, m1ssel, dlsel, zsel, dH, Om, Ol, w0, wm)

    log_wt_sel = log_dN_sel .- log_psel
    log_wt2_sel = 2.0 .* log_wt_sel

    log_mu_sel = logsumexp(log_wt_sel) - log(ndraw)
    log_s2_sel = logsubexp(logsumexp(log_wt2_sel) - 2.0*log(ndraw), 2.0*log_mu_sel - log(ndraw))

    neff = exp(2.0*log_mu_sel - log_s2_sel)

    # if (neff < 4*nobs) 
    #     #@warn "not enough samples to estimate selection integral " + string(neff) + " " + string(nobs)
    #     Turing.@addlogprob! -Inf
    #     println("neff not enough", " ", neff, " ", nobs, " ", H0, " ", Om, " ", alpha, " ", beta, " ", mmin, " ", mmax, " ", smin, " ", smax, " ", gamma, " ", kappa, " ", zp)
    # end
    
    #neff ends
    
    for i in 1:nobs

      dls = dlsamp[:,i]

      if maximum(dls) > maximum(dLinterp) || minimum(dls) < minimum(dLinterp)
            Turing.@addlogprob! -Inf
      else


      zs = [z_of_d(dls[j]) for j in 1:nsamp]
      m1s = m1samp[:,i]./(1 .+ zs)
      m2s = m1s .* qsamp[:,i]

      log_dN_mmz = log_dNdm1dm2dz(m1s, m2s, dls, zs, alpha, beta, mmin, smin, mmax, smax, gamma, zp, kappa, dH, Om, Ol, w0, wm, memax, memin)
      log_dN_mdl = log_dNdm1dqdd_of_dm1dm2dz(log_dN_mmz, m1s, dls, zs, dH, Om, Ol, w0, wm)

      log_dN_sum = logsumexp(log_dN_mdl)# - logwt_samp[:,i])
      Turing.@addlogprob! (log_dN_sum - log(nsamp))
      end

    end

    Turing.@addlogprob! (-nobs*(log_mu_sel))# - nobs/(2*neff)))
    end
                        
end
# Out:
# highz_pop_simple (generic function with 1 method)

# %%
θ0 = [67.74, 0.3075, 4.8, 2.1, 7.1, 49.0, 0.17, 0.15, 0.2, 3.1, 1.9]
# Sampler params
δ = 0.65 # Acceptance ratio
max_depth = 7 # Tree depth
init_ϵ = 0.2
Niter = 1000
model = highz_pop_simple(Nobs, Nsamp, Nsel, Ndraw, m1s_samp, qs_samp, dls_samp, logwt_samp, m1sel_cut, qsel_cut, dlsel_cut, logpsel_cut)
Nthread = 1
# Out:
# 1

# %%
Turing.setchunksize(length(θ0))
sampler = Turing.NUTS(Niter, δ; metricT = AdvancedHMC.DenseEuclideanMetric, max_depth=max_depth, init_ϵ=init_ϵ)
if Nthread > 1
    trace = sample(model, sampler, MCMCThreads(), Niter, Nthread, init_theta = θ0, progress=true)
else
    trace = sample(model, sampler, Niter, init_theta = θ0, progress=true)
end
# Out:
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:   2%|▋                                        |  ETA: 0:38:32┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:   6%|██▎                                      |  ETA: 2:32:24┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:   6%|██▌                                      |  ETA: 2:27:42┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:   7%|██▉                                      |  ETA: 2:17:58┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:   8%|███▏                                     |  ETA: 2:15:39┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:   8%|███▎                                     |  ETA: 2:10:04┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:   8%|███▌                                     |  ETA: 2:05:00┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:   9%|███▊                                     |  ETA: 2:00:41┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  10%|███▉                                     |  ETA: 2:01:24┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  10%|████▏                                    |  ETA: 2:02:18┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  10%|████▎                                    |  ETA: 2:00:12┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  11%|████▌                                    |  ETA: 1:56:29┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  12%|████▊                                    |  ETA: 1:54:49┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  12%|████▉                                    |  ETA: 1:51:59┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  12%|█████▏                                   |  ETA: 1:49:12┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  13%|█████▍                                   |  ETA: 1:45:56┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  15%|██████▏                                  |  ETA: 1:38:14┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  16%|██████▍                                  |  ETA: 1:35:50┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  18%|███████▋                                 |  ETA: 1:29:01┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  19%|███████▊                                 |  ETA: 1:27:08┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  20%|████████                                 |  ETA: 1:25:49┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  20%|████████▎                                |  ETA: 1:24:33┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  22%|████████▉                                |  ETA: 1:19:22┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  22%|█████████▎                               |  ETA: 1:16:34┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  25%|██████████▎                              |  ETA: 1:10:00┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  26%|██████████▋                              |  ETA: 1:08:12┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  30%|████████████▎                            |  ETA: 0:59:57┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  31%|████████████▊                            |  ETA: 0:58:16┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  36%|██████████████▌                          |  ETA: 0:51:25┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  36%|███████████████                          |  ETA: 0:50:04┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  38%|███████████████▊                         |  ETA: 0:47:32┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  47%|███████████████████▎                     |  ETA: 0:37:59┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  48%|███████████████████▌                     |  ETA: 0:37:27┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  50%|████████████████████▎                    |  ETA: 0:35:38┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  52%|█████████████████████▍                   |  ETA: 0:33:08┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  52%|█████████████████████▌                   |  ETA: 0:32:37┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  58%|███████████████████████▋                 |  ETA: 0:27:58┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  60%|████████████████████████▋                |  ETA: 0:25:46┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  67%|███████████████████████████▌             |  ETA: 0:20:13┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  68%|███████████████████████████▋             |  ETA: 0:19:51┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  72%|█████████████████████████████▍           |  ETA: 0:16:58┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  72%|█████████████████████████████▌           |  ETA: 0:16:39┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# ┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  74%|██████████████████████████████▏          |  ETA: 0:15:37┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  79%|████████████████████████████████▍        |  ETA: 0:12:00┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  80%|█████████████████████████████████        |  ETA: 0:11:04┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  87%|███████████████████████████████████▋     |  ETA: 0:07:19┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  90%|████████████████████████████████████▉    |  ETA: 0:05:35┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  90%|█████████████████████████████████████▏   |  ETA: 0:05:18┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  91%|█████████████████████████████████████▎   |  ETA: 0:05:00┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  94%|██████████████████████████████████████▊  |  ETA: 0:03:01┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling:  97%|███████████████████████████████████████▊ |  ETA: 0:01:38┌ Warning: The current proposal will be rejected due to numerical error(s).
# │   isfinite.((θ, r, ℓπ, ℓκ)) = (true, false, false, false)
# └ @ AdvancedHMC /Users/cosmonana/.julia/packages/AdvancedHMC/yd6UP/src/hamiltonian.jl:47
# Sampling: 100%|█████████████████████████████████████████| Time: 0:53:48
# Chains MCMC chain (1000×23×1 Array{Float64, 3}):
#
# Iterations        = 1001:1:2000
# Number of chains  = 1
# Samples per chain = 1000
# Wall duration     = 3254.09 seconds
# Compute duration  = 3254.09 seconds
# parameters        = alpha, gamma, kappa, Om, mmin, H0, smin, mmax, beta, smax, zp
# internals         = lp, n_steps, is_accept, acceptance_rate, log_density, hamiltonian_energy, hamiltonian_energy_error, max_hamiltonian_energy_error, tree_depth, numerical_error, step_size, nom_step_size
#
# Summary Statistics
#   parameters      mean       std   naive_se      mcse        ess      rhat   e ⋯
#       Symbol   Float64   Float64    Float64   Float64    Float64   Float64     ⋯
#
#           H0   74.0080    5.6607     0.1790    0.6348    26.8715    1.0657     ⋯
#           Om    0.3567    0.0626     0.0020    0.0067    66.3589    1.0523     ⋯
#        alpha    5.0668    0.1679     0.0053    0.0067   532.5254    1.0000     ⋯
#         beta    2.0148    0.1782     0.0056    0.0073   583.1776    0.9993     ⋯
#         mmin    7.0764    0.3057     0.0097    0.0308    78.1002    1.0265     ⋯
#         mmax   49.0397    1.5723     0.0497    0.1029   210.8236    1.0202     ⋯
#         smin    0.1811    0.0144     0.0005    0.0007   530.2000    1.0008     ⋯
#         smax    0.1480    0.0098     0.0003    0.0004   786.5251    0.9994     ⋯
#        gamma    0.1618    0.1762     0.0056    0.0082   370.3043    0.9994     ⋯
#        kappa    2.5417    0.4149     0.0131    0.0206   343.8081    0.9995     ⋯
#           zp    2.3278    0.5657     0.0179    0.0339   256.0146    0.9993     ⋯
#                                                                 1 column omitted
#
# Quantiles
#   parameters      2.5%     25.0%     50.0%     75.0%     97.5%
#       Symbol   Float64   Float64   Float64   Float64   Float64
#
#           H0   64.8720   69.8138   73.6354   77.5209   86.2737
#           Om    0.2405    0.3109    0.3558    0.4068    0.4666
#        alpha    4.7595    4.9495    5.0664    5.1831    5.4070
#         beta    1.6774    1.8860    2.0186    2.1337    2.3539
#         mmin    6.5141    6.8732    7.0626    7.2799    7.7232
#         mmax   46.0722   47.9064   48.9562   50.0456   52.1981
#         smin    0.1549    0.1702    0.1807    0.1912    0.2091
#         smax    0.1302    0.1412    0.1477    0.1546    0.1670
#        gamma   -0.1812    0.0477    0.1565    0.2719    0.5390
#        kappa    1.7724    2.2740    2.5269    2.8005    3.3876
#           zp    1.2810    1.9555    2.2849    2.6742    3.5165

# %%
plot(trace)

# %%
write("chains/chains_highz_pop_zevolve_lh_obs_1000_ndraw4000_step1000_trace_no_evolve_fit.jls", trace)

# %%
ztemp = expm1.(range(0, log(11), length=1024))
dtemp = [d_of_z(ztemp[i]) for i in 1:1024]

g = scatter(dls_true, m1s_true.*(1 .+ zs_true),  markersize=0.2, size=(400,400), legend=false)  #color=:oslo
plot!(dtemp, mmax_true .* (1 .+ ztemp), color = :orange)

# %%
p1 = scatter(dls_true, m1s_true.*(1 .+ zs_true), alpha = 0.4,color="dodgerblue3", markersize=0.2, size=(400,400), title=L"\mathrm{Smoothed~Power~Law~Model}")  #color=:oslo
plot!(dtemp, mmax_true .* (1 .+ ztemp), color = :orange3, xlabel = L"d_L(\mathrm{Gpc})", ylabel = L"m_{1,det}(M_{\odot})")
p2 = scatter(dls_true_mp, m1s_true_mp.*(1 .+ zs_true_mp), alpha = 0.4,color="dodgerblue3", markersize=0.2, size=(400,400), title=L"\mathrm{Power~Law+Peak~Model}")  #color=:oslo
plot!(dtemp, 60 .* (1 .+ ztemp), line=(2, 0.6, :orange3))
plot!(dtemp, 35 .* (1 .+ ztemp),line=(2, :dash, 0.6, :orange3), xlabel = L"d_L(\mathrm{Gpc})", ylabel = L"m_{1,det}(M_{\odot})")
plotd = plot(p1, p2,size=(800,400), legend=false)
savefig(plotd,"highzdata.png")

# %%
g = scatter(dls_true_mp, m1s_true_mp,  markersize=0.2, size=(400,400), legend=false)  #color=:oslo
plot!(dtemp, 60 .* (1 .+ [0 for i in 1:1024]), color = :orange)
plot!(dtemp, 35 .* (1 .+ [0 for i in 1:1024]))

# %%
histogram(m1s_true_mp)

# %%
chains_highz_pop_simple = mapreduce(c -> sample(highz_pop_simple(Nobs, Nsamp, Nsel, Ndraw, m1s_samp, qs_samp, dls_samp, logwt_samp, m1sel_cut, qsel_cut, dlsel_cut, logpsel_cut),  NUTS(), 600), chainscat, 1:2)

# %%
plot(chains_highz_pop_simple)

# %%
write("chains/chains_highz_pop_zmax=15_obs_2000_ndraw8000_step1000_chains2.jls", chains_highz_pop_simple)

# %%
thetapost = [10.0011, 0.0103, 0.0005, 99.9995, 4.7625, 99.9030, 0.1694, 0.2660, 5.7659, 8.3462, 2.8396]
#[67.74, 0.3075, 4.8, 2.1, 7.1, 49.0, 0.17, 0.15, 0.2, 3.1, 1.9]
#[10.0011, 0.0103, 0.0005, 99.9995, 4.7625, 99.9030, 0.1694, 0.2660, 5.7659, 8.3462, 2.8396]
theta = thetapost

H0 = theta[1] #truncated(Normal(70.0, 10.0), 0, 100)
Om = theta[2] # truncated(Normal(0.3, 0.1), 0, 0.5)
#Ok ~ truncated(Normal(0, 0.1), -1, 1) # Linearly related to Ol (=1-Ok-Om) (the sampled variable), so no Jacobian 
#w0 ~ Normal(-1.0, 0.2)
#wm ~ Normal(0.0, 0.2)

# mass function prior
alpha = theta[3]
beta = theta[4]
mmin = theta[5]
mmax = theta[6]
smin = theta[7]
smax = theta[8]

# merger rate density prior
gamma = theta[9]
kappa= theta[10]
zp = theta[11]

Ok = 0
w0 = -1.0
wm = 0
dH=299.792/H0

Ol = 1 - Ok - Om
nobs = Nobs
nsamp = Nsamp

log_dN = Array{Array{Real}}(undef, nobs)

cosmosim = cosmology(h=H0/100, OmegaK = Ok, OmegaM=Om, OmegaR=0)
dLinterp = [luminosity_dist(cosmosim, zinterp[i])/1000/ u"Mpc" for i in 1:ninterp]
z_of_d = LinearInterpolation(dLinterp, zinterp)
d_of_z = LinearInterpolation(zinterp, dLinterp)

for i in 1:nobs

  dLs = dls_samp[:,i]

  zs = [z_of_d(dLs[j]) for j in 1:nsamp]
  m1s = m1s_samp[:,i]./(1 .+ zs)
  m2s = m1s .* qs_samp[:,i]

  log_dN_mmz = log_dNdm1dm2dz(m1s, m2s, dLs, zs, alpha, beta, mmin, smin, mmax, smax, gamma, zp, kappa, dH, Om, Ol, w0, wm)
  log_dN_mdl = log_dNdm1dqdd_of_dm1dm2dz(log_dN_mmz, m1s, dLs, zs, dH, Om, Ol, w0, wm)

  log_dN_sum = logsumexp(log_dN_mdl) # - logwt_samp[:,i])
  println(i, " ", log_dN_mdl)
  log_dN[i] = log_dN_mdl


end 

m1sa = zeros(nobs)
qsa = zeros(nobs)
m2sa = zeros(nobs)
dlsa = zeros(nobs)
Neff_samps = Array{Real}(undef, nobs)

for i in 1:nobs
    wts = exp.(log_dN[i] .- maximum(log_dN[i]))
    j = draw_sample_index(wts)
    # println(wts)
    # println(Array(log_dN))
    m1sa[i] = m1s_samp[j,i]
    qsa[i] = qs_samp[j,i]
    m2sa[i] = qs_samp[j,i]*m1s_samp[j,i]
    dlsa[i] = dls_samp[j,i]
    Neff_samps[i] = effective_sample_number(wts)
end

# wts_sel = exp.(log_wt_sel .- maximum(log_wt_sel))
# js = draw_sample_index(wts_sel, nobs)
# m1s_sel_draw = m1ssel[js]
# qs_sel_draw = qsel[js]
# zs_sel_draw = zsel[js]
# dls_sel_draw = d_of_z.(zs_sel_draw)

# %%
zsa = [z_of_d(dlsa[i]) for i in 1:nobs]
histogram(m1sa, alpha=0.4, norm=true)
histogram!(m1s_samp[1,:],alpha=0.4, norm=true)
histogram!(m1sel_cut.*(1 .+ [z_of_d(dlsel_cut[i]) for i in 1:Nsel]),alpha=0.4, norm=true)

# %%
histogram(qsa,alpha=0.4, norm=true)
histogram!(qs_samp[1,:],alpha=0.4, norm=true)
histogram!(qsel_cut,alpha=0.4, norm=true)

# %%
histogram(dlsa,alpha=0.4, norm=true)
histogram!(dls_samp[1,:],alpha=0.4, norm=true)
histogram!(dlsel_cut,alpha=0.4, norm=true)

# %%
write("chains_highz_pop_zmax=15_obs_3000_ndraw600000_step2000_chains1.jls", chains_highz_pop_simple)
